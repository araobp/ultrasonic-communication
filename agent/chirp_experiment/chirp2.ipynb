# %% [markdown]
# # Chirp experiment
#
# June 1, 2018
#
# Repetetive frequency-sweep tone (20msec) is transmitted from mini speaker to MEMS mic.
#
# The speaker is a very cheap one.

# %%
import matplotlib.pyplot as plt
import pandas

# %% [markdown]
# ## Frequency sweep range: 16000Hz - 18000Hz (20cm)

# %%
df = pandas.read_csv("./16000_18000_100.0(kHz)_M2A.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")

# %% [markdown]
# ## Frequency sweep range: 16000Hz - 18000Hz (1m)

# %%
df = pandas.read_csv("./16000_18000_1m_100.0(kHz)_M1.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")

# %% [markdown]
# ## Frequency sweep range: 16000Hz - 20000Hz (1m)

# %%
df = pandas.read_csv("./16000_20000_1m_100.0(kHz)_M2A.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")

# %% [markdown]
# ## Frequency sweep range: 18000Hz - 20000Hz (1m)

# %%
df = pandas.read_csv("./18000_20000_1m_100.0(kHz)_M2A.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")

# %% [markdown]
# ## Frequency sweep range: 16000Hz - 18000Hz (1m, 2x)

# %%
df = pandas.read_csv("./16000_18000_2x_100.0(kHz)_M2A.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")

# %%
df = pandas.read_csv("./100.0(kHz)_M1.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")

# %% [markdown]
# ## Noise from paper rubbing
#
# Paper rubbing generates noise over the frequency-sweep range.

# %%
df = pandas.read_csv("./paper_100.0(kHz)_M1.fft")
plt.figure(figsize=(13, 4), dpi=80)
df.plot(x="Frequency(Hz)", y="Magnitude(dB)")
df.plot(x="Frequency(Hz)", y="Magnitude")
