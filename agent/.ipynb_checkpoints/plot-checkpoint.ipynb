# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("./1526342048.1443574_100.0(kHz)_M2A.csv", delimiter=',')

# %%
print(df)
# Out:
#       Frequency(Hz)    Magnitude  Magnitude(dB)
# 0               0.0     1.000000       0.000000
# 1              48.8     1.000000       0.000000
# 2              97.7     1.000000       0.000000
# 3             146.5     1.000000       0.000000
# 4             195.3     1.000000       0.000000
# 5             244.1     1.000000       0.000000
# 6             293.0     1.000000       0.000000
# 7             341.8     1.000000       0.000000
# 8             390.6     1.000000       0.000000
# 9             439.5     1.000000       0.000000
# 10            488.3     1.000000       0.000000
# 11            537.1     1.000000       0.000000
# 12            585.9     1.000000       0.000000
# 13            634.8     1.000000       0.000000
# 14            683.6     1.000000       0.000000
# 15            732.4     1.000000       0.000000
# 16            781.2     1.000000       0.000000
# 17            830.1     1.000000       0.000000
# 18            878.9     1.000000       0.000000
# ...

# %%
df.plot(x='Frequency(Hz)', y='Magnitude(dB)')
